# %%
# pip install -U "langchain[openai]"
# Out:
# Requirement already satisfied: langchain[openai] in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (1.3.15)
# Collecting langchain[openai]
#   Downloading langchain-1.4.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting langchain-core<2.0.0,>=1.6.0 (from langchain[openai])
#   Downloading langchain_core-1.6.2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langchain[openai]) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langchain[openai]) (2.13.4)
# Collecting langchain-openai (from langchain[openai])
#   Downloading langchain_openai-1.6.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain[openai]) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain[openai]) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain[openai]) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain[openai]) (0.10.18)
# Requirement already satisfied: packaging>=23.2.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain[openai]) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain[openai]) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain[openai]) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain[openai]) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain[openai]) (0.17.0)
# Requirement already satisfied: anyio in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain[openai]) (4.14.2)
# Requirement already satisfied: certifi in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain[openai]) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain[openai]) (1.0.9)
# Requirement already satisfied: idna in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain[openai]) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain[openai]) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain[openai]) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain[openai]) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain[openai]) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain[openai]) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain[openai]) (4.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain[openai]) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain[openai]) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain[openai]) (15.0.1)
# Requirement already satisfied: distro>=1.7.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain[openai]) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain[openai]) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain[openai]) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain[openai]) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain[openai]) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[openai]) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain[openai]) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain[openai]) (2.7.0)
# Requirement already satisfied: openai<4.0.0,>=2.45.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langchain-openai->langchain[openai]) (2.53.0)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai->langchain[openai])
#   Downloading tiktoken-0.14.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from openai<4.0.0,>=2.45.0->langchain-openai->langchain[openai]) (0.16.0)
# Requirement already satisfied: tqdm>4 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from openai<4.0.0,>=2.45.0->langchain-openai->langchain[openai]) (4.70.0)
# Requirement already satisfied: regex in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai->langchain[openai]) (2026.7.19)
# Requirement already satisfied: colorama in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from tqdm>4->openai<4.0.0,>=2.45.0->langchain-openai->langchain[openai]) (0.4.6)
# Downloading langchain-1.4.0-py3-none-any.whl (161 kB)
# Downloading langchain_core-1.6.2-py3-none-any.whl (571 kB)
#    ---------------------------------------- 0.0/571.7 kB ? eta -:--:--
#    ------------------------------------ --- 524.3/571.7 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 571.7/571.7 kB 2.5 MB/s  0:00:00
# Downloading langchain_openai-1.6.0-py3-none-any.whl (125 kB)
# Downloading tiktoken-0.14.0-cp312-cp312-win_amd64.whl (941 kB)
#    ---------------------------------------- 0.0/941.2 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/941.2 kB ? eta -:--:--
#    --------------------------------- ------ 786.4/941.2 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 941.2/941.2 kB 1.8 MB/s  0:00:00
# Installing collected packages: tiktoken, langchain-core, langchain-openai, langchain
#
#    ---------------------------------------- 0/4 [tiktoken]
#   Attempting uninstall: langchain-core
#    ---------------------------------------- 0/4 [tiktoken]
#     Found existing installation: langchain-core 1.5.4
#    ---------------------------------------- 0/4 [tiktoken]
#    ---------- ----------------------------- 1/4 [langchain-core]
#     Uninstalling langchain-core-1.5.4:
#    ---------- ----------------------------- 1/4 [langchain-core]
#       Successfully uninstalled langchain-core-1.5.4
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    -------------------- ------------------- 2/4 [langchain-openai]
#    -------------------- ------------------- 2/4 [langchain-openai]
#    -------------------- ------------------- 2/4 [langchain-openai]
#    -------------------- ------------------- 2/4 [langchain-openai]
#    -------------------- ------------------- 2/4 [langchain-openai]
#    -------------------- ------------------- 2/4 [langchain-openai]
#    -------------------- ------------------- 2/4 [langchain-openai]
#    -------------------- ------------------- 2/4 [langchain-openai]
#   Attempting uninstall: langchain
#    -------------------- ------------------- 2/4 [langchain-openai]
#     Found existing installation: langchain 1.3.15
#    -------------------- ------------------- 2/4 [langchain-openai]
#     Uninstalling langchain-1.3.15:
#    -------------------- ------------------- 2/4 [langchain-openai]
#       Successfully uninstalled langchain-1.3.15
#    -------------------- ------------------- 2/4 [langchain-openai]
#    ------------------------------ --------- 3/4 [langchain]
#    ------------------------------ --------- 3/4 [langchain]
#    ------------------------------ --------- 3/4 [langchain]
#    ------------------------------ --------- 3/4 [langchain]
#    ------------------------------ --------- 3/4 [langchain]
#    ------------------------------ --------- 3/4 [langchain]
#    ------------------------------ --------- 3/4 [langchain]
#    ------------------------------ --------- 3/4 [langchain]
#    ------------------------------ --------- 3/4 [langchain]
#    ------------------------------ --------- 3/4 [langchain]
#    ------------------------------ --------- 3/4 [langchain]
#    ------------------------------ --------- 3/4 [langchain]
#    ---------------------------------------- 4/4 [langchain]
#
# Successfully installed langchain-1.4.0 langchain-core-1.6.2 langchain-openai-1.6.0 tiktoken-0.14.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["OPENAI_API_KEY"] = ""
model = init_chat_model("gpt-5.4", temperature=0.7)

# %%
# pip install langchain-ollama
# Out:
# Collecting langchain-ollama
#   Downloading langchain_ollama-1.1.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.21 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langchain-ollama) (1.6.2)
# Collecting ollama<1.0.0,>=0.6.1 (from langchain-ollama)
#   Downloading ollama-0.6.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.10.18)
# Requirement already satisfied: packaging>=23.2.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (26.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.17.0)
# Requirement already satisfied: anyio in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (4.14.2)
# Requirement already satisfied: certifi in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (1.0.9)
# Requirement already satisfied: idna in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (3.1.1)
# Requirement already satisfied: distro>=1.7.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (4.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\sayee\AppData\Local\Programs\Python\Python312\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.21->langchain-ollama) (2.7.0)
# Downloading langchain_ollama-1.1.0-py3-none-any.whl (31 kB)
# Downloading ollama-0.6.2-py3-none-any.whl (15 kB)
# Installing collected packages: ollama, langchain-ollama
#
#    ---------------------------------------- 0/2 [ollama]
#    -------------------- ------------------- 1/2 [langchain-ollama]
#    -------------------- ------------------- 1/2 [langchain-ollama]
#    ---------------------------------------- 2/2 [langchain-ollama]
#
# Successfully installed langchain-ollama-1.1.0 ollama-0.6.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_ollama import ChatOllama

# Create local model
model = ChatOllama(
    model="llama3.2",
    temperature=0.7
)

# Ask the model
response = model.invoke("Hello, how are you?")

# Print response
print(response.content)
# Out:
# Hello! I'm just a language model, so I don't have emotions or feelings like humans do, but I'm functioning properly and ready to assist you with any questions or tasks you may have. How can I help you today?

# %%
response = model.invoke("Hello, how are you?")

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(
    model="llama3.2",
    temperature=0.7
)

# %%
response = model.invoke("Hello, how are you?")
print(response.content)
# Out:
# I'm just a language model, so I don't have emotions or feelings like humans do, but I'm functioning properly and ready to help you with any questions or tasks you may have! How can I assist you today?

# %%
response = model.invoke("Hello, how are you?")

# %%
import streamlit as st
from langchain_ollama import ChatOllama

st.title("AI Chatbot")

model = ChatOllama(
    model="llama3.2",
    temperature=0.7
)

user_message = st.chat_input("Ask me anything...")

if user_message:
    st.chat_message("user").write(user_message)

    response = model.invoke(user_message)

    st.chat_message("assistant").write(response.content)
# Out:
# 2026-09-07 18:17:05.717 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-07 18:17:06.800
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\sayee\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-09-07 18:17:06.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-07 18:17:06.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-07 18:17:07.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-07 18:17:07.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-07 18:17:07.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-07 18:17:07.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-07 18:17:07.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import streamlit as st
from langchain_ollama import ChatOllama

st.title("My AI Chatbot")

model = ChatOllama(
    model="llama3.2",
    temperature=0.7
)

user_message = st.chat_input("Ask me anything...")

if user_message:

    st.chat_message("user").write(user_message)

    response = model.invoke(user_message)

    st.chat_message("assistant").write(response.content)
# Out:
# 2026-09-07 18:19:27.350 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-07 18:19:27.361 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-07 18:19:27.364 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-07 18:19:27.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-07 18:19:27.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-07 18:19:27.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-07 18:19:27.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-09-07 18:19:27.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
